# %%
import requests
import pandas as pd

# %% [markdown]
# Due to the limitations of Here API to send only 1000 requests per day I used 3 different accounts to save time and geocode the data

# %% [markdown]
# # Geocoding Employees addresses

# %%
employees=pd.read_csv("Employee_Addresses.csv")
employees
# Out:
#                                              address  employee_id
# 0      98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1           237 Accacia St, Daly City, CA 94014, USA         2081
# 2       1835 Folsom St, San Francisco, CA 94103, USA          178
# 3     170 Cambridge St, San Francisco, CA 94134, USA           50
# 4        16 Roanoke St, San Francisco, CA 94131, USA         1863
# ...                                              ...          ...
# 2186     72 Topeka Ave, San Francisco, CA 94124, USA          980
# 2187         330 Oliver St, Daly City, CA 94014, USA          385
# 2188     94 W View Ave, San Francisco, CA 94134, USA          692
# 2189   1599 Geneva Ave, San Francisco, CA 94112, USA         1025
# 2190     499 Treat Ave, San Francisco, CA 94110, USA         1782
#
# [2191 rows x 2 columns]

# %%
#first token
headers1={"Authorization":"Bearer eyJhbGciOiJSUzUxMiIsImN0eSI6IkpXVCIsImlzcyI6IkhFUkUiLCJhaWQiOiIydGdHSkxuMWRSRXF6UWVHRHdCMiIsImlhdCI6MTY3MDcxNjAxNCwiZXhwIjoxNjcwODAyNDE0LCJraWQiOiJqMSJ9..Ik2oz8fdc6Z2Tqmaewv88Yb6rypRjnrO0wGn9SSGi06b9aPTPYAoF6P-5uYYJF5nxm0bkkd7QzMeZFQTWoSJBy1gVauayNK2uhtDFkAcOKm_jT1TcHz7i_HrYzRpNK7LkUOVuIhOkCjkQZFLUKXFneyPVEQ8dVyiZNbT_GR0JPV331do2xrPT_ZiAVhC8BgzOt8m2hNFc32ksH4cNWRSS7ull1Oi9HNUIuW2G6Q4z5N6hhiWOsRLNC8Gn771sdLdiQhrrGmZFERpQZwXFjN3M9-CPn1bv-n9dlv9HURId-vltm4X2gtBAialFQntHGF5eetytJtJJ5PSHXfSopTr2Q"}

# %% [markdown]
# I am extracting latitude and longitiude only from the data

# %%
employees_positions1=[]
for i in range(0,1000):
    employees_positions1.append(requests.get('https://geocode.search.hereapi.com/v1/geocode?q='+employees['address'][i],headers=headers1).json()['items'][0]['position'])
employees_positions1 
#1000 requests sent
# Out:
# [{'lat': 37.72763, 'lng': -122.42734},
#  {'lat': 37.70418, 'lng': -122.41582},
#  {'lat': 37.76793, 'lng': -122.4151},
#  {'lat': 37.72966, 'lng': -122.41972},
#  {'lat': 37.73624, 'lng': -122.43132},
#  {'lat': 37.70735, 'lng': -122.4472},
#  {'lat': 37.77921, 'lng': -122.41519},
#  {'lat': 37.70679, 'lng': -122.41357},
#  {'lat': 37.77934, 'lng': -122.41586},
#  {'lat': 37.73345, 'lng': -122.42299},
#  {'lat': 37.76849, 'lng': -122.43107},
#  {'lat': 37.76582, 'lng': -122.4092},
#  {'lat': 37.70382, 'lng': -122.41466},
#  {'lat': 37.73708, 'lng': -122.39986},
#  {'lat': 37.72134, 'lng': -122.42941},
#  {'lat': 37.7061, 'lng': -122.45062},
#  {'lat': 37.71931, 'lng': -122.4285},
#  {'lat': 37.79508, 'lng': -122.44045},
#  {'lat': 37.71611, 'lng': -122.43771},
#  {'lat': 37.71038, 'lng': -122.41127},
#  {'lat': 37.78338, 'lng': -122.39571},
#  {'lat': 37.7714, 'lng': -122.41494},
#  {'lat': 37.72684, 'lng': -122.43012},
#  {'lat': 37.73512, 'lng': -122.40496},
# ...

# %%
employees_positions_0_1000=employees[0:1000].join(pd.DataFrame(employees_positions1,index=[i for i in range(0,1000)]))
employees_positions_0_1000
# Out:
#                                             address  employee_id       lat  \
# 0     98 Edinburgh St, San Francisco, CA 94112, USA          206  37.72763
# 1          237 Accacia St, Daly City, CA 94014, USA         2081  37.70418
# 2      1835 Folsom St, San Francisco, CA 94103, USA          178  37.76793
# 3    170 Cambridge St, San Francisco, CA 94134, USA           50  37.72966
# 4       16 Roanoke St, San Francisco, CA 94131, USA         1863  37.73624
# ..                                              ...          ...       ...
# 995    1422 Market St, San Francisco, CA 94102, USA         1414  37.77628
# 996  226 Edinburgh St, San Francisco, CA 94112, USA           76  37.72556
# 997         69 Ney St, San Francisco, CA 94112, USA         1586  37.73021
# 998    311 Arleta Ave, San Francisco, CA 94134, USA          417  37.71434
# 999      230 Mateo St, San Francisco, CA 94131, USA         1570  37.73599
#
#            lng
# 0   -122.42734
# 1   -122.41582
# 2   -122.41510
# ...

# %%
#second token
headers2 = {"Authorization": "Bearer eyJhbGciOiJSUzUxMiIsImN0eSI6IkpXVCIsImlzcyI6IkhFUkUiLCJhaWQiOiJkV296NXpNeXRoRkR1MkNLemY4UyIsImlhdCI6MTY3MDcxNjIyNSwiZXhwIjoxNjcwODAyNjI1LCJraWQiOiJqMSJ9..aewB2WEV4Upkd9awPfAg7fzNDoO0MsV3AuiGHArjZOlieN3opCNB0FuDXBJ8FzMpeEdu8fkKlKjZ3APkYtHFqzz89Ma9a6UQi36I0W2_ho_1ne0OuHOZyMapD8u1096j4yJ8qU-XyHTkyMx4Rb-5jyXlAsBQbwraoz1d9_gBnTdW9BfD1NL4Y0i51KFBwMnNKlYHgFRm_cZzZ8qYqKgXjvlyLrBHR195mkLgk-5s60bVOKk8UO2JzWbrcl4-3bHkOy-nLkMOOqembCmtxuD7ik8XQeU5tbQmX9kiLj0ma-oRmfTOnFbcUNCgitKTY0TigZo1_geExKGPW-HOss7boQ"}

# %%
employees_positions2=[]
for i in range(1000,2000):
    employees_positions2.append(requests.get('https://geocode.search.hereapi.com/v1/geocode?q='+employees['address'][i],headers=headers2).json()['items'][0]['position'])
employees_positions2 
#1000 request sent
# Out:
# [{'lat': 37.71988, 'lng': -122.42885},
#  {'lat': 37.76878, 'lng': -122.42431},
#  {'lat': 37.7362, 'lng': -122.42967},
#  {'lat': 37.76991, 'lng': -122.41529},
#  {'lat': 37.73384, 'lng': -122.41872},
#  {'lat': 37.74695, 'lng': -122.4227},
#  {'lat': 37.73104, 'lng': -122.43025},
#  {'lat': 37.7336, 'lng': -122.43009},
#  {'lat': 37.73553, 'lng': -122.41969},
#  {'lat': 37.73641, 'lng': -122.44798},
#  {'lat': 37.76655, 'lng': -122.40797},
#  {'lat': 37.71571, 'lng': -122.43558},
#  {'lat': 37.72625, 'lng': -122.4237},
#  {'lat': 37.72841, 'lng': -122.42883},
#  {'lat': 37.75023, 'lng': -122.44523},
#  {'lat': 37.78891, 'lng': -122.44485},
#  {'lat': 37.73641, 'lng': -122.42989},
#  {'lat': 37.72069, 'lng': -122.43042},
#  {'lat': 37.79631, 'lng': -122.44313},
#  {'lat': 37.76732, 'lng': -122.41239},
#  {'lat': 37.78041, 'lng': -122.41879},
#  {'lat': 37.74398, 'lng': -122.42369},
#  {'lat': 37.77007, 'lng': -122.41513},
#  {'lat': 37.79508, 'lng': -122.44045},
# ...

# %%
employees_positions_1000_2000=employees[1000:2000].join(pd.DataFrame(employees_positions2,index=[i for i in range(1000,2000)]))
employees_positions_1000_2000
# Out:
#                                                address  employee_id       lat  \
# 1000      899 Persia Ave, San Francisco, CA 94112, USA         1757  37.71988
# 1001       98 Brosnan St, San Francisco, CA 94103, USA            5  37.76878
# 1002      440 Chenery St, San Francisco, CA 94131, USA         1069  37.73620
# 1003      1681 Folsom St, San Francisco, CA 94103, USA          762  37.76991
# 1004      478 Benton Ave, San Francisco, CA 94110, USA          676  37.73384
# ...                                                ...          ...       ...
# 1995      531 Persia Ave, San Francisco, CA 94112, USA         1880  37.72115
# 1996          35 Fell St, San Francisco, CA 94102, USA         1225  37.77634
# 1997         30 Grove St, San Francisco, CA 94102, USA         1731  37.77916
# 1998          221 Accacia St, Daly City, CA 94014, USA          113  37.70454
# 1999  3068 California St, San Francisco, CA 94115, USA         2051  37.78779
#
#             lng
# ...

# %%
#third token
headers3={"Authorization":"Bearer eyJhbGciOiJSUzUxMiIsImN0eSI6IkpXVCIsImlzcyI6IkhFUkUiLCJhaWQiOiJBUThPaXFncWRVUkhINjJFbjhUaSIsImlhdCI6MTY3MDcxNzE4NywiZXhwIjoxNjcwODAzNTg3LCJraWQiOiJqMSJ9..cVwGJSiQ36QS4VJ5th9JYV-pbds9Blk-n7CvD1hc-JmjYc11o1Pq0KhRu06BFBw6zjDpKlNY2MQPKMIXrR1bgEzvK75KkpG4sYLq6ZfO5_G-_4hcH-yjHig8BQFIpf_5gogt0WzHo_4YtZVT5NSPrqrapZtVERUju1DH3wuZCK9q-RfrpRmVKlNtzuqSBl4MDVv0Vg5TTKX1UViXE-SyFZtRKbXya4ILxWXTOdKRkyd-oorp9TcUlRhiy9m0rWylChdlxkKDhESpQmyfOREJfwVNXP8GmCst1edBVmtwhSKMz0Bw8iRghhZ9kKQKmnPQOYWev3O2VPPEPXYSKroZhA"}

# %%
employees_positions3=[]
for i in range(2000,len(employees)):
    employees_positions3.append(requests.get('https://geocode.search.hereapi.com/v1/geocode?q='+employees['address'][i],headers=headers3).json()['items'][0]['position'])
employees_positions3
#191 requests sent
# Out:
# [{'lat': 37.74814, 'lng': -122.44857},
#  {'lat': 37.71714, 'lng': -122.43802},
#  {'lat': 37.72902, 'lng': -122.42182},
#  {'lat': 37.79081, 'lng': -122.44659},
#  {'lat': 37.71417, 'lng': -122.43749},
#  {'lat': 37.79121, 'lng': -122.44658},
#  {'lat': 37.70596, 'lng': -122.41241},
#  {'lat': 37.79446, 'lng': -122.44305},
#  {'lat': 37.77966, 'lng': -122.41663},
#  {'lat': 37.72841, 'lng': -122.43237},
#  {'lat': 37.71, 'lng': -122.44535},
#  {'lat': 37.77102, 'lng': -122.40731},
#  {'lat': 37.70596, 'lng': -122.41241},
#  {'lat': 37.76582, 'lng': -122.4092},
#  {'lat': 37.71857, 'lng': -122.43909},
#  {'lat': 37.70475, 'lng': -122.41615},
#  {'lat': 37.73443, 'lng': -122.41189},
#  {'lat': 37.73493, 'lng': -122.40246},
#  {'lat': 37.73415, 'lng': -122.40012},
#  {'lat': 37.738, 'lng': -122.4252},
#  {'lat': 37.72505, 'lng': -122.43159},
#  {'lat': 37.79062, 'lng': -122.44721},
#  {'lat': 37.71538, 'lng': -122.40908},
#  {'lat': 37.72157, 'lng': -122.42923},
# ...

# %%
employees_positions_2000_end=employees[2000:len(employees)].join(pd.DataFrame(employees_positions3,index=[i for i in range(2000,len(employees))]))
employees_positions_2000_end
# Out:
#                                                 address  employee_id  \
# 2000  808 Twin Peaks Blvd, San Francisco, CA 94131, USA           19
# 2001         737 Paris St, San Francisco, CA 94112, USA         1789
# 2002       681 Silver Ave, San Francisco, CA 94134, USA         1107
# 2003      3125 Jackson St, San Francisco, CA 94115, USA          900
# 2004         243 Rolph St, San Francisco, CA 94112, USA          447
# ...                                                 ...          ...
# 2186        72 Topeka Ave, San Francisco, CA 94124, USA          980
# 2187            330 Oliver St, Daly City, CA 94014, USA          385
# 2188        94 W View Ave, San Francisco, CA 94134, USA          692
# 2189      1599 Geneva Ave, San Francisco, CA 94112, USA         1025
# 2190        499 Treat Ave, San Francisco, CA 94110, USA         1782
#
#            lat        lng
# 2000  37.74814 -122.44857
# 2001  37.71714 -122.43802
# 2002  37.72902 -122.42182
# 2003  37.79081 -122.44659
# ...

# %%
#concat the 3 dataframes
total=pd.concat([employees_positions_0_1000,employees_positions_1000_2000,employees_positions_2000_end],axis=0)
total
# Out:
#                                              address  employee_id       lat  \
# 0      98 Edinburgh St, San Francisco, CA 94112, USA          206  37.72763
# 1           237 Accacia St, Daly City, CA 94014, USA         2081  37.70418
# 2       1835 Folsom St, San Francisco, CA 94103, USA          178  37.76793
# 3     170 Cambridge St, San Francisco, CA 94134, USA           50  37.72966
# 4        16 Roanoke St, San Francisco, CA 94131, USA         1863  37.73624
# ...                                              ...          ...       ...
# 2186     72 Topeka Ave, San Francisco, CA 94124, USA          980  37.73410
# 2187         330 Oliver St, Daly City, CA 94014, USA          385  37.70531
# 2188     94 W View Ave, San Francisco, CA 94134, USA          692  37.73079
# 2189   1599 Geneva Ave, San Francisco, CA 94112, USA         1025  37.71244
# 2190     499 Treat Ave, San Francisco, CA 94110, USA         1782  37.76231
#
#             lng
# 0    -122.42734
# 1    -122.41582
# ...

# %%
total.to_csv('Employees_positions.csv')

# %% [markdown]
# # Geocoding the Bus Stops locations

# %%
bus_stops=pd.read_csv('Bus_Stops.csv')
bus_stops.head()
# Out:
#    Street_One         Street_Two
# 0  MISSION ST          ITALY AVE
# 1  MISSION ST  NEW MONTGOMERY ST
# 2  MISSION ST            01ST ST
# 3  MISSION ST            20TH ST
# 4  MISSION ST         FREMONT ST

# %%
bus_positions=bus_stops.apply(lambda x: requests.get('https://geocode.search.hereapi.com/v1/geocode?q='+x['Street_One']+' '+x['Street_Two']+' san francisco',headers=headers3).json()['items'][0]['position'],axis=1)

# %%
bus_Stops=bus_stops.join(pd.DataFrame(list(bus_positions)))
bus_Stops.head()
# Out:
#    Street_One         Street_Two       lat        lng
# 0  MISSION ST          ITALY AVE  37.71847 -122.43953
# 1  MISSION ST  NEW MONTGOMERY ST  37.78745 -122.40050
# 2  MISSION ST            01ST ST  37.79323 -122.39288
# 3  MISSION ST            20TH ST  37.75863 -122.41904
# 4  MISSION ST         FREMONT ST  37.79047 -122.39669

# %%
bus_Stops.to_csv('Bus_Stops_with_positions.csv')
